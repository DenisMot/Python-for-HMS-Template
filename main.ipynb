# %% [markdown]
# # Run all notebooks in the project

# %% [markdown]
# ## 1. Run notebooks/ecg_00.ipynb

# %%
# %run notebooks/ecg_00.ipynb
# Out:
# Data directory: data
# ECG data path: data/test_data/ECG_hz.txt
# Loading ECG data from: data/test_data/ECG_hz.txt
# ecg_00.ipynb finished

# %% [markdown]
# ## 2. Run template.ipynb

# %%
# %run template.ipynb
# Out:
# # Template for a Jupyter Notebook
# 07 August 2026, 15:12:17
# by Denis Mottet (and Copilot)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Switched to 'inline' backend for HTML export
